# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/xuzebin/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
filepath = '/Users/xuzebin/Projects/big-data-analytics/zebinxu/NYPD_Complaint_Data_Historic.csv'
df = pd.read_csv(filepath, dtype = {'PREM_TYP_DESC':str, 'PARKS_NM':str})

# %%
df.describe()
# Out:
# /Users/xuzebin/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#          CMPLNT_NUM         KY_CD         PD_CD   ADDR_PCT_CD    X_COORD_CD  \
# count  5.101231e+06  5.101231e+06  5.096657e+06  5.100841e+06  4.913085e+06
# mean   5.499733e+08  2.932191e+02  4.179772e+02  6.346322e+01  1.004610e+06
# std    2.597636e+08  1.480821e+02  2.179312e+02  3.444424e+01  2.144742e+04
# min    1.000002e+08  1.010000e+02  1.010000e+02  1.000000e+00  9.133190e+05
# 25%    3.250451e+08  1.170000e+02           NaN           NaN           NaN
# 50%    5.499458e+08  3.410000e+02           NaN           NaN           NaN
# 75%    7.748865e+08  3.510000e+02           NaN           NaN           NaN
# max    9.999999e+08  8.810000e+02  9.750000e+02  1.230000e+02  1.067298e+06
#
#          Y_COORD_CD      Latitude     Longitude
# count  4.913085e+06  4.913085e+06  4.913085e+06
# ...

# %%
cols = df.loc[df['KY_CD'].fillna('0')]

# %%
cols['KY_CD'].head(10)
# Out:
# 113    106
# 101    578
# 117    341
# 344    106
# 344    106
# 106    347
# 235    106
# 118    578
# 344    106
# 341    109
# Name: KY_CD, dtype: int64

# %%
cols['KY_CD'].min()
cols['KY_CD'].max()
# Out:
# 578

# %%
df['KY_CD'].value_counts().plot(kind='bar', figsize=(15,4))
plt.show()

# %%
df['OFNS_DESC'].value_counts().plot(kind='bar', figsize=(15,4))
plt.show()

# %%
df['PD_CD'].value_counts().plot(kind='bar', figsize=(20,4))
plt.show()

# %%
df['PD_DESC'].value_counts().plot(kind='bar', figsize=(20,4))
plt.show()

# %%
# df11 = pd.DataFrame({'col11': df['CRM_ATPT_CPTD_CD'].value_counts()})
# df11.plot(kind='pie', subplots=True)
df['CRM_ATPT_CPTD_CD'].value_counts().plot(kind='pie', figsize=(8, 8))
plt.show()

# %%
df['LAW_CAT_CD'].value_counts().plot(kind='pie', figsize=(8, 8))
plt.show()

# %%
df['JURIS_DESC'].value_counts().plot(kind='pie', figsize=(8, 8))
plt.show()
